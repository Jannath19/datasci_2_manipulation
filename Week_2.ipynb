# %% [markdown]
# <a href="https://colab.research.google.com/github/Jannath19/datasci_2_manipulation/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data Cleaning
#
# In this section, I performed data cleaning on the healthcare dataset:
#
# - I loaded the dataset using Pandas.
# - I identified and handle missing values by dropping rows with missing data.
# - I removed duplicate rows and columns from the dataset.
# - I cleaned the column names by stripping spaces and converting them to lowercase.

# %% [markdown]
# Load Packages

# %%
import pandas as pd

# %% [markdown]
# Load Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK2/data/healthcare_data_cleaning.csv')
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes            missing           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
# 104999            No                Yes           Cash        Dr. Brown
#
#        Disease Diagnosed Medication Prescribed Type of Appointment  \
# 0                    Flu                 Med_E             General
# 1                    Flu                 Med_B          Specialist
# 2               Covid-19                 Med_D             General
# 3                    Flu                 Med_A             General
# 4                   None                 Med_C          Specialist
# ...                  ...                   ...                 ...
# 104995          Covid-19                 Med_E          Specialist
# 104996          Covid-19                 Med_C             General
# 104997           Allergy                 Med_D           Follow-Up
# 104998          Covid-19                 Med_A           Follow-Up
# 104999           Allergy                 Med_D             General
#
#        Average Heart Rate Average BP Height (in cm) Weight (in kg)  \
# 0                      66        111            183             70
# 1                      59    missing            174             58
# 2                      79        119            161             56
# 3                      99        115            171             52
# 4                      93         89            186             87
# ...                   ...        ...            ...            ...
# 104995                 65        112            169             61
# 104996            missing        111            165             67
# 104997                 89        118            179             71
# 104998                 74        123            167             75
# 104999                 77        140            167             62
#
#            Payment Due ($) Last Visit (days ago) Visit Duration (mins)  \
# 0        65.45721578126224                   193                    92
# 1       430.68365678679174                   195               missing
# 2        315.0709305262176               missing                    37
# 3        320.2998987723972                   175                   108
# 4        264.2147372473319                   188                   113
# ...                    ...                   ...                   ...
# 104995  309.16444606680665                   183                    10
# 104996             missing                   191                    47
# 104997   320.8304180033907                   172                    39
# 104998   5.341231420036174                   180                    79
# 104999  454.94983945860804                   167                    81
#
#        Number of Tests Prescription Cost ($)
# 0                    5     15.71751735532889
# 1                    4     80.78647284463952
# 2                    2      64.3921393009105
# 3                    2     8.872859215315316
# 4                    3     77.48311304645532
# ...                ...                   ...
# 104995               3     63.20478776719894
# 104996               2    113.86764025370326
# 104997               3    35.622420232475356
# 104998         missing     124.4083409893742
# 104999         missing     87.91060149353706
#
# [105000 rows x 20 columns]

# %%
# Check for missing values
missing_values = df.isnull().sum()
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes            missing           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
# 104999            No                Yes           Cash        Dr. Brown
#
#        Disease Diagnosed Medication Prescribed Type of Appointment  \
# 0                    Flu                 Med_E             General
# 1                    Flu                 Med_B          Specialist
# 2               Covid-19                 Med_D             General
# 3                    Flu                 Med_A             General
# 4                   None                 Med_C          Specialist
# ...                  ...                   ...                 ...
# 104995          Covid-19                 Med_E          Specialist
# 104996          Covid-19                 Med_C             General
# 104997           Allergy                 Med_D           Follow-Up
# 104998          Covid-19                 Med_A           Follow-Up
# 104999           Allergy                 Med_D             General
#
#        Average Heart Rate Average BP Height (in cm) Weight (in kg)  \
# 0                      66        111            183             70
# 1                      59    missing            174             58
# 2                      79        119            161             56
# 3                      99        115            171             52
# 4                      93         89            186             87
# ...                   ...        ...            ...            ...
# 104995                 65        112            169             61
# 104996            missing        111            165             67
# 104997                 89        118            179             71
# 104998                 74        123            167             75
# 104999                 77        140            167             62
#
#            Payment Due ($) Last Visit (days ago) Visit Duration (mins)  \
# 0        65.45721578126224                   193                    92
# 1       430.68365678679174                   195               missing
# 2        315.0709305262176               missing                    37
# 3        320.2998987723972                   175                   108
# 4        264.2147372473319                   188                   113
# ...                    ...                   ...                   ...
# 104995  309.16444606680665                   183                    10
# 104996             missing                   191                    47
# 104997   320.8304180033907                   172                    39
# 104998   5.341231420036174                   180                    79
# 104999  454.94983945860804                   167                    81
#
#        Number of Tests Prescription Cost ($)
# 0                    5     15.71751735532889
# 1                    4     80.78647284463952
# 2                    2      64.3921393009105
# 3                    2     8.872859215315316
# 4                    3     77.48311304645532
# ...                ...                   ...
# 104995               3     63.20478776719894
# 104996               2    113.86764025370326
# 104997               3    35.622420232475356
# 104998         missing     124.4083409893742
# 104999         missing     87.91060149353706
#
# [105000 rows x 20 columns]

# %%
#Check the size and shape of the DataFrame
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 105000
# Number of columns: 20

# %%
# Check the first few rows of your DataFrame to inspect column names
print(df.head())
# Out:
#   Patient Age  Gender  City of Residence State of Residence Has Insurance  \
# 0          45   Other         West Brian           Kentucky           Yes
# 1          25  Female   East Jocelynfurt           Colorado            No
# 2          51   Other  South Lindseyland               Ohio           Yes
# 3          18  Female         Taylorfort       Pennsylvania           Yes
# 4          48  Female          Birdmouth            Montana            No
#
#   Visited Last Month Payment Method Preferred Doctor Disease Diagnosed  \
# 0                Yes      Insurance     Dr. Williams               Flu
# 1                Yes           Card      Dr. Johnson               Flu
# 2                 No           Cash     Dr. Williams          Covid-19
# 3            missing           Cash     Dr. Williams               Flu
# 4                 No      Insurance        Dr. Brown              None
#
#   Medication Prescribed Type of Appointment Average Heart Rate Average BP  \
# 0                 Med_E             General                 66        111
# 1                 Med_B          Specialist                 59    missing
# 2                 Med_D             General                 79        119
# 3                 Med_A             General                 99        115
# 4                 Med_C          Specialist                 93         89
#
#   Height (in cm) Weight (in kg)     Payment Due ($) Last Visit (days ago)  \
# 0            183             70   65.45721578126224                   193
# 1            174             58  430.68365678679174                   195
# 2            161             56   315.0709305262176               missing
# 3            171             52   320.2998987723972                   175
# 4            186             87   264.2147372473319                   188
#
#   Visit Duration (mins) Number of Tests Prescription Cost ($)
# 0                    92               5     15.71751735532889
# 1               missing               4     80.78647284463952
# 2                    37               2      64.3921393009105
# 3                   108               2     8.872859215315316
# 4                   113               3     77.48311304645532

# %%
# Handle missing values (e.g., drop rows with missing values)
df.dropna(inplace=True)

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Remove duplicate columns (if any)
df = df.loc[:, ~df.columns.duplicated()]

# Clean column names
df.columns = df.columns.str.strip().str.lower()
df
# Out:
#        patient age  gender  city of residence state of residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
#
#        has insurance visited last month payment method preferred doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes            missing           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104994            No                 No           Card     Dr. Williams
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
#
#        disease diagnosed medication prescribed type of appointment  \
# 0                    Flu                 Med_E             General
# 1                    Flu                 Med_B          Specialist
# 2               Covid-19                 Med_D             General
# 3                    Flu                 Med_A             General
# 4                   None                 Med_C          Specialist
# ...                  ...                   ...                 ...
# 104994               Flu                 Med_B           Emergency
# 104995          Covid-19                 Med_E          Specialist
# 104996          Covid-19                 Med_C             General
# 104997           Allergy                 Med_D           Follow-Up
# 104998          Covid-19                 Med_A           Follow-Up
#
#        average heart rate average bp height (in cm) weight (in kg)  \
# 0                      66        111            183             70
# 1                      59    missing            174             58
# 2                      79        119            161             56
# 3                      99        115            171             52
# 4                      93         89            186             87
# ...                   ...        ...            ...            ...
# 104994                 68        109            172             75
# 104995                 65        112            169             61
# 104996            missing        111            165             67
# 104997                 89        118            179             71
# 104998                 74        123            167             75
#
#            payment due ($) last visit (days ago) visit duration (mins)  \
# 0        65.45721578126224                   193                    92
# 1       430.68365678679174                   195               missing
# 2        315.0709305262176               missing                    37
# 3        320.2998987723972                   175                   108
# 4        264.2147372473319                   188                   113
# ...                    ...                   ...                   ...
# 104994   488.0316041186948                   167                    25
# 104995  309.16444606680665                   183                    10
# 104996             missing                   191                    47
# 104997   320.8304180033907                   172                    39
# 104998   5.341231420036174                   180                    79
#
#        number of tests prescription cost ($)
# 0                    5     15.71751735532889
# 1                    4     80.78647284463952
# 2                    2      64.3921393009105
# 3                    2     8.872859215315316
# 4                    3     77.48311304645532
# ...                ...                   ...
# 104994               5     69.54228578689846
# 104995               3     63.20478776719894
# 104996               2    113.86764025370326
# 104997               3    35.622420232475356
# 104998         missing     124.4083409893742
#
# [100000 rows x 20 columns]

# %%
# Clean the 'patient age' column by replacing 'missing' values with NaN
df['patient age'] = pd.to_numeric(df['patient age'], errors='coerce')
df
# Out:
#         patient age  gender  city of residence state of residence  \
# 0              45.0   Other         West Brian           Kentucky
# 1              25.0  Female   East Jocelynfurt           Colorado
# 2              51.0   Other  South Lindseyland               Ohio
# 3              18.0  Female         Taylorfort       Pennsylvania
# 4              48.0  Female          Birdmouth            Montana
# ...             ...     ...                ...                ...
# 104994         53.0  Female      Michelleburgh       South Dakota
# 104995         74.0   Other       West Anthony           Oklahoma
# 104996         37.0    Male          Mckeetown               Utah
# 104997         51.0  Female   Lake Lisachester           Nebraska
# 104998          NaN  Female       Heidiborough            missing
#
#        has insurance visited last month payment method preferred doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes            missing           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104994            No                 No           Card     Dr. Williams
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
#
#        disease diagnosed medication prescribed type of appointment  \
# 0                    Flu                 Med_E             General
# 1                    Flu                 Med_B          Specialist
# 2               Covid-19                 Med_D             General
# 3                    Flu                 Med_A             General
# 4                   None                 Med_C          Specialist
# ...                  ...                   ...                 ...
# 104994               Flu                 Med_B           Emergency
# 104995          Covid-19                 Med_E          Specialist
# 104996          Covid-19                 Med_C             General
# 104997           Allergy                 Med_D           Follow-Up
# 104998          Covid-19                 Med_A           Follow-Up
#
#        average heart rate average bp height (in cm) weight (in kg)  \
# 0                      66        111            183             70
# 1                      59    missing            174             58
# 2                      79        119            161             56
# 3                      99        115            171             52
# 4                      93         89            186             87
# ...                   ...        ...            ...            ...
# 104994                 68        109            172             75
# 104995                 65        112            169             61
# 104996            missing        111            165             67
# 104997                 89        118            179             71
# 104998                 74        123            167             75
#
#            payment due ($) last visit (days ago) visit duration (mins)  \
# 0        65.45721578126224                   193                    92
# 1       430.68365678679174                   195               missing
# 2        315.0709305262176               missing                    37
# 3        320.2998987723972                   175                   108
# 4        264.2147372473319                   188                   113
# ...                    ...                   ...                   ...
# 104994   488.0316041186948                   167                    25
# 104995  309.16444606680665                   183                    10
# 104996             missing                   191                    47
# 104997   320.8304180033907                   172                    39
# 104998   5.341231420036174                   180                    79
#
#        number of tests prescription cost ($)
# 0                    5     15.71751735532889
# 1                    4     80.78647284463952
# 2                    2      64.3921393009105
# 3                    2     8.872859215315316
# 4                    3     77.48311304645532
# ...                ...                   ...
# 104994               5     69.54228578689846
# 104995               3     63.20478776719894
# 104996               2    113.86764025370326
# 104997               3    35.622420232475356
# 104998         missing     124.4083409893742
#
# [100000 rows x 20 columns]

# %%
# Define custom age groups based on 'patient age'
bins = [0, 18, 30, 40, 50, 60, 70, float('inf')]
labels = ['0-17', '18-29', '30-39', '40-49', '50-59', '60-69', '70+']

# Create a new column 'age_group' based on 'patient age'
df['age_group'] = pd.cut(df['patient age'], bins=bins, labels=labels, right=False)

# Step 5: Create new columns based on existing ones
# Calculate age from 'patient age' column (assuming 'patient age' is in years)
df['age'] = df['patient age']

# Step 6: Clean 'visit duration (mins)' column and convert to numeric
df['visit duration (mins)'] = pd.to_numeric(df['visit duration (mins)'], errors='coerce')

# Step 7: Aggregate data and compute summary statistics
# Calculate average visit duration by gender and age group
pivot_table = df.pivot_table(values='visit duration (mins)', index='gender', columns='age_group', aggfunc='mean')
df
# Out:
#         patient age  gender  city of residence state of residence  \
# 0              45.0   Other         West Brian           Kentucky
# 1              25.0  Female   East Jocelynfurt           Colorado
# 2              51.0   Other  South Lindseyland               Ohio
# 3              18.0  Female         Taylorfort       Pennsylvania
# 4              48.0  Female          Birdmouth            Montana
# ...             ...     ...                ...                ...
# 104994         53.0  Female      Michelleburgh       South Dakota
# 104995         74.0   Other       West Anthony           Oklahoma
# 104996         37.0    Male          Mckeetown               Utah
# 104997         51.0  Female   Lake Lisachester           Nebraska
# 104998          NaN  Female       Heidiborough            missing
#
#        has insurance visited last month payment method preferred doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes            missing           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104994            No                 No           Card     Dr. Williams
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
#
#        disease diagnosed medication prescribed  ... average bp height (in cm)  \
# 0                    Flu                 Med_E  ...        111            183
# 1                    Flu                 Med_B  ...    missing            174
# 2               Covid-19                 Med_D  ...        119            161
# 3                    Flu                 Med_A  ...        115            171
# 4                   None                 Med_C  ...         89            186
# ...                  ...                   ...  ...        ...            ...
# 104994               Flu                 Med_B  ...        109            172
# 104995          Covid-19                 Med_E  ...        112            169
# 104996          Covid-19                 Med_C  ...        111            165
# 104997           Allergy                 Med_D  ...        118            179
# 104998          Covid-19                 Med_A  ...        123            167
#
#        weight (in kg)     payment due ($) last visit (days ago)  \
# 0                  70   65.45721578126224                   193
# 1                  58  430.68365678679174                   195
# 2                  56   315.0709305262176               missing
# 3                  52   320.2998987723972                   175
# 4                  87   264.2147372473319                   188
# ...               ...                 ...                   ...
# 104994             75   488.0316041186948                   167
# 104995             61  309.16444606680665                   183
# 104996             67             missing                   191
# 104997             71   320.8304180033907                   172
# 104998             75   5.341231420036174                   180
#
#        visit duration (mins) number of tests  prescription cost ($) age_group  \
# 0                       92.0               5      15.71751735532889     40-49
# 1                        NaN               4      80.78647284463952     18-29
# 2                       37.0               2       64.3921393009105     50-59
# 3                      108.0               2      8.872859215315316     18-29
# 4                      113.0               3      77.48311304645532     40-49
# ...                      ...             ...                    ...       ...
# 104994                  25.0               5      69.54228578689846     50-59
# 104995                  10.0               3      63.20478776719894       70+
# 104996                  47.0               2     113.86764025370326     30-39
# 104997                  39.0               3     35.622420232475356     50-59
# 104998                  79.0         missing      124.4083409893742       NaN
#
#          age
# 0       45.0
# 1       25.0
# 2       51.0
# 3       18.0
# 4       48.0
# ...      ...
# 104994  53.0
# 104995  74.0
# 104996  37.0
# 104997  51.0
# 104998   NaN
#
# [100000 rows x 22 columns]

# %% [markdown]
# ## Step 2: Data Transformation
#
# In this step, I performed various data transformations on the healthcare dataset to prepare it for analysis. Below are the details of the transformations:
#
# ### 1. Creating Custom Age Groups
# To analyze age-related trends, I created custom age groups based on the 'patient age' column. Here are the age group categories:
# - 0-17
# - 18-29
# - 30-39
# - 40-49
# - 50-59
# - 60-69
# - 70+
#
# ### 2. Calculating Age
# I calculated the 'age' of patients based on the 'patient age' column.
#
# ### 3. Cleaning 'Visit Duration'
# I cleaned the 'visit duration (mins)' column by converting it to numeric data type.
#
# ### 4. Aggregating Data
# - I calculated the average visit duration by gender.
# - I created a pivot table to analyze 'visit duration (mins)' by gender and age group. The pivot table allows for multi-dimensional analysis.

# %%
# Import the Polars library
import polars as pl
import time

# Define the URL for your dataset
url = 'https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK2/data/healthcare_data_cleaning.csv'

# Capture the start time
start_time = time.time()

# Load the dataset using Polars
df_polars = pl.read_csv(url)

# Capture the end time
end_time = time.time()

# Calculate the load time
load_time_polars = end_time - start_time
df
# Out:
#         patient age  gender  city of residence state of residence  \
# 0              45.0   Other         West Brian           Kentucky
# 1              25.0  Female   East Jocelynfurt           Colorado
# 2              51.0   Other  South Lindseyland               Ohio
# 3              18.0  Female         Taylorfort       Pennsylvania
# 4              48.0  Female          Birdmouth            Montana
# ...             ...     ...                ...                ...
# 104994         53.0  Female      Michelleburgh       South Dakota
# 104995         74.0   Other       West Anthony           Oklahoma
# 104996         37.0    Male          Mckeetown               Utah
# 104997         51.0  Female   Lake Lisachester           Nebraska
# 104998          NaN  Female       Heidiborough            missing
#
#        has insurance visited last month payment method preferred doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes            missing           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104994            No                 No           Card     Dr. Williams
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
#
#        disease diagnosed medication prescribed  ... average bp height (in cm)  \
# 0                    Flu                 Med_E  ...        111            183
# 1                    Flu                 Med_B  ...    missing            174
# 2               Covid-19                 Med_D  ...        119            161
# 3                    Flu                 Med_A  ...        115            171
# 4                   None                 Med_C  ...         89            186
# ...                  ...                   ...  ...        ...            ...
# 104994               Flu                 Med_B  ...        109            172
# 104995          Covid-19                 Med_E  ...        112            169
# 104996          Covid-19                 Med_C  ...        111            165
# 104997           Allergy                 Med_D  ...        118            179
# 104998          Covid-19                 Med_A  ...        123            167
#
#        weight (in kg)     payment due ($) last visit (days ago)  \
# 0                  70   65.45721578126224                   193
# 1                  58  430.68365678679174                   195
# 2                  56   315.0709305262176               missing
# 3                  52   320.2998987723972                   175
# 4                  87   264.2147372473319                   188
# ...               ...                 ...                   ...
# 104994             75   488.0316041186948                   167
# 104995             61  309.16444606680665                   183
# 104996             67             missing                   191
# 104997             71   320.8304180033907                   172
# 104998             75   5.341231420036174                   180
#
#        visit duration (mins) number of tests  prescription cost ($) age_group  \
# 0                       92.0               5      15.71751735532889     40-49
# 1                        NaN               4      80.78647284463952     18-29
# 2                       37.0               2       64.3921393009105     50-59
# 3                      108.0               2      8.872859215315316     18-29
# 4                      113.0               3      77.48311304645532     40-49
# ...                      ...             ...                    ...       ...
# 104994                  25.0               5      69.54228578689846     50-59
# 104995                  10.0               3      63.20478776719894       70+
# 104996                  47.0               2     113.86764025370326     30-39
# 104997                  39.0               3     35.622420232475356     50-59
# 104998                  79.0         missing      124.4083409893742       NaN
#
#          age
# 0       45.0
# 1       25.0
# 2       51.0
# 3       18.0
# 4       48.0
# ...      ...
# 104994  53.0
# 104995  74.0
# 104996  37.0
# 104997  51.0
# 104998   NaN
#
# [100000 rows x 22 columns]
